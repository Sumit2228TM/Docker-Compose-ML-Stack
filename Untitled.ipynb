# %%
# !pip install psycopg2-binary

# %%
import psycopg2

conn = psycopg2.connect(
    host="postgres",
    database="mldata",
    user="mluser",
    password="mlpassword"
)

cur = conn.cursor()
cur.execute("SELECT * FROM predictions")
cur.fetchall()
# Out:
# [(1, 1.0, 2.0, datetime.datetime(2026, 1, 9, 15, 33, 0, 886290)),
#  (2, 2.5, 5.0, datetime.datetime(2026, 1, 9, 15, 33, 0, 886290)),
#  (3, 3.7, 7.4, datetime.datetime(2026, 1, 9, 15, 33, 0, 886290)),
#  (4, 2000.0, 4000.0, datetime.datetime(2026, 1, 9, 15, 36, 19, 551823)),
#  (5,
#   2000.82197836,
#   4001.64395672,
#   datetime.datetime(2026, 1, 9, 15, 36, 34, 798686))]
